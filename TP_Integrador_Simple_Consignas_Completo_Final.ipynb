# %% [markdown]
# # Trabajo Práctico Integrador
# ## Introducción al análisis de datos con Python y GitHub
#
# Este práctico está pensado como una primera experiencia de análisis de datos.
# No vamos a importar archivos externos. Los datos estarán cargados directamente en el código.
#
# La idea es trabajar con datos de estudiantes y responder preguntas simples usando Python, librerías y gráficos.

# %% [markdown]
# ## Objetivo del trabajo
#
# Desarrollar un pequeño análisis de datos educativos que permita observar:
#
# - cantidad de estudiantes;
# - promedio de edad;
# - promedio de notas;
# - estudiantes aprobados y desaprobados;
# - relación entre trabajo y rendimiento;
# - uso de IA;
# - horas de estudio y nota final.
#
# Al final, el trabajo debe subirse a GitHub.

# %% [markdown]
# ## Datos del trabajo
#
# Vamos a usar una lista de diccionarios.
# Cada diccionario representa a un estudiante.

# %%
estudiantes = [
    {"nombre": "Ana", "edad": 22, "trabaja": "Sí", "horas_estudio": 5, "nota": 8, "usa_ia": "Sí"},
    {"nombre": "Juan", "edad": 28, "trabaja": "Sí", "horas_estudio": 2, "nota": 5, "usa_ia": "No"},
    {"nombre": "Sofía", "edad": 20, "trabaja": "No", "horas_estudio": 6, "nota": 9, "usa_ia": "Sí"},
    {"nombre": "Pedro", "edad": 24, "trabaja": "No", "horas_estudio": 3, "nota": 6, "usa_ia": "No"},
    {"nombre": "Lucía", "edad": 31, "trabaja": "Sí", "horas_estudio": 4, "nota": 7, "usa_ia": "Sí"},
    {"nombre": "Martín", "edad": 19, "trabaja": "No", "horas_estudio": 2, "nota": 4, "usa_ia": "No"},
    {"nombre": "Carla", "edad": 26, "trabaja": "Sí", "horas_estudio": 7, "nota": 9, "usa_ia": "Sí"},
    {"nombre": "Diego", "edad": 23, "trabaja": "No", "horas_estudio": 4, "nota": 7, "usa_ia": "Sí"},
]

# %% [markdown]
# ## Actividad 1: convertir los datos en una tabla
#
# 1.   Elemento de la lista
# 2.   Elemento de la lista
#
#
#
# Importá pandas y convertí la lista `estudiantes` en un DataFrame llamado `df`.
#
# Luego mostrá la tabla.

# %%
# Escribí tu código acá
import pandas as pd
df = pd.DataFrame(estudiantes)
print(df)
# Out:
#    nombre  edad trabaja  horas_estudio  nota usa_ia
# 0     Ana    22      Sí              5     8     Sí
# 1    Juan    28      Sí              2     5     No
# 2   Sofía    20      No              6     9     Sí
# 3   Pedro    24      No              3     6     No
# 4   Lucía    31      Sí              4     7     Sí
# 5  Martín    19      No              2     4     No
# 6   Carla    26      Sí              7     9     Sí
# 7   Diego    23      No              4     7     Sí

# %% [markdown]
# ## Actividad 2: calcular indicadores generales
#
# Calculá y mostrá:
#
# 1. cantidad total de estudiantes;
# 2. promedio de edad;
# 3. promedio de nota;
# 4. promedio de horas de estudio.

# %%
# Escribí tu código acá
total_estudiantes = len(df)
promedio_edad = df["edad"].mean()
promedio_nota = df["nota"].mean()
promedio_estudio = df["horas_estudio"].mean()
print(f"Cantidad total de estudiantes: {total_estudiantes}")
print(f"Promedio de edad: {promedio_edad}")
print(f"Promedio de nota entre los estudiantes: {promedio_nota}")
print(f"Promedio de horas de estudio de los estudiantes: {promedio_estudio}")
# Out:
# Cantidad total de estudiantes: 8
# Promedio de edad: 24.125
# Promedio de nota entre los estudiantes: 6.875
# Promedio de horas de estudio de los estudiantes: 4.125

# %% [markdown]
# ## Actividad 3: aprobados y desaprobados
#
# Consideramos aprobado a quien tiene nota igual o mayor a 6.
#
# Creá una nueva columna llamada `estado`, con los valores:
#
# - `Aprobado`
# - `Desaprobado`
#
# Luego contá cuántos estudiantes aprobaron y cuántos desaprobaron.

# %%
# Escribí tu código acá
# Nueva columna
def determinar_estado(nota):
    if nota >= 6:
        return "Aprobado"
    else:
        return "Desaprobado"

df["estado"] = df["nota"].apply(determinar_estado)
print(df)

#Cant aprobados y cant desaprobados
conteo = df["estado"].value_counts()
print(f"Cantidad de alumnos aprobados y desaprobados: {conteo}")
# Out:
#    nombre  edad trabaja  horas_estudio  nota usa_ia       estado
# 0     Ana    22      Sí              5     8     Sí     Aprobado
# 1    Juan    28      Sí              2     5     No  Desaprobado
# 2   Sofía    20      No              6     9     Sí     Aprobado
# 3   Pedro    24      No              3     6     No     Aprobado
# 4   Lucía    31      Sí              4     7     Sí     Aprobado
# 5  Martín    19      No              2     4     No  Desaprobado
# 6   Carla    26      Sí              7     9     Sí     Aprobado
# 7   Diego    23      No              4     7     Sí     Aprobado
# Cantidad de alumnos aprobados y desaprobados: estado
# Aprobado       6
# Desaprobado    2
# Name: count, dtype: int64

# %% [markdown]
# ## Actividad 4: trabajo y rendimiento
#
# Separá los estudiantes en dos grupos:
#
# - quienes trabajan;
# - quienes no trabajan.
#
# Luego calculá el promedio de nota de cada grupo.

# %%
# Escribí tu código acá
#Separo estudiantes
estudiantes_trabajan = df[df["trabaja"] == "Sí"]
estudiantes_no_trabajan = df[df["trabaja"] == "No"]
print(f"Estudiantes que trabajan: \n {estudiantes_trabajan}")
print(f"Estudiantes que no trabajan: \n {estudiantes_no_trabajan}")

#Saco promedios
promedio_trabaja = estudiantes_trabajan["nota"].mean()
promedio_no_trabaja = estudiantes_no_trabajan["nota"].mean()
print(f"Promedio de estudiantes que trabajan: {promedio_trabaja}")
print(f"Promedio de estudiantes que no trabajan: {promedio_no_trabaja}")
# Out:
# Estudiantes que trabajan:
#    nombre  edad trabaja  horas_estudio  nota usa_ia       estado
# 0    Ana    22      Sí              5     8     Sí     Aprobado
# 1   Juan    28      Sí              2     5     No  Desaprobado
# 4  Lucía    31      Sí              4     7     Sí     Aprobado
# 6  Carla    26      Sí              7     9     Sí     Aprobado
# Estudiantes que no trabajan:
#     nombre  edad trabaja  horas_estudio  nota usa_ia       estado
# 2   Sofía    20      No              6     9     Sí     Aprobado
# 3   Pedro    24      No              3     6     No     Aprobado
# 5  Martín    19      No              2     4     No  Desaprobado
# 7   Diego    23      No              4     7     Sí     Aprobado
# Promedio de estudiantes que trabajan: 7.25
# Promedio de estudiantes que no trabajan: 6.5

# %% [markdown]
# ## Actividad 5: uso de IA
#
# Contá:
#
# - cuántos estudiantes usan IA;
# - cuántos estudiantes no usan IA.

# %%
# Escribí tu código acá
for estudiante in estudiantes:
  estudiante_usa_ia = len(df[df["usa_ia"] == "Sí"])
  estudiante_no_usa_ia = len(df[df["usa_ia"] == "No"])
print(f"Estudiantes que usan IA: {estudiante_usa_ia}")
print(f"Estudiantes que no usan IA: {estudiante_no_usa_ia}")
# Out:
# Estudiantes que usan IA: 5
# Estudiantes que no usan IA: 3

# %% [markdown]
# ## Actividad 6: nota más alta y nota más baja
#
# Mostrá:
#
# - el nombre del estudiante con la nota más alta;
# - el nombre del estudiante con la nota más baja.

# %%
# Escribí tu código acá
nota_mas_alta = df["nota"].max()
nota_mas_baja = df["nota"].min()
estudiante_nota_alta = df[df["nota"] == nota_mas_alta]
estudiante_nota_baja = df[df["nota"] == nota_mas_baja]
print(f"Estudiante con nota más alta: \n {estudiante_nota_alta}")
print(f"Estudiante con nota más baja: \n {estudiante_nota_baja}")
# Out:
# Estudiante con nota más alta:
#    nombre  edad trabaja  horas_estudio  nota usa_ia    estado
# 2  Sofía    20      No              6     9     Sí  Aprobado
# 6  Carla    26      Sí              7     9     Sí  Aprobado
# Estudiante con nota más baja:
#     nombre  edad trabaja  horas_estudio  nota usa_ia       estado
# 5  Martín    19      No              2     4     No  Desaprobado

# %% [markdown]
# ## Actividad 7: gráficos
#
# Realizá al menos dos gráficos:
#
# 1. gráfico de barras con las notas de cada estudiante;
# 2. gráfico de dispersión con horas de estudio y nota final.
#
# Podés usar `matplotlib`.

# %%
# Escribí tu código acá
import matplotlib.pyplot as plt

#Gráfico de notas de cada estudiante

plt.bar(df["nombre"], df["nota"])
plt.xlabel("Estudiantes")
plt.ylabel("Notas")
plt.title("Notas de los estudiantes")
plt.show()

#Gráfico de dispersión con horas de estudio y nota final

plt.scatter(df["horas_estudio"], df["nota"])
plt.xlabel("Horas de estudio")
plt.ylabel("Nota final")
plt.title("Relación entre horas de estudio y nota final")
plt.show()

# %% [markdown]
# ## Actividad 8: conclusiones
#
# Escribí una conclusión breve respondiendo:
#
# 1. ¿Cuál fue el promedio general de notas?
# 2. ¿La mayoría aprobó o desaprobó?
# 3. ¿Hay diferencias entre quienes trabajan y quienes no trabajan?
# 4. ¿Qué información puede servirle a una institución educativa?

# %% [markdown]
# El promedio generla de notas observado en el grupo de estudiantes fue de 6.875, la mayoría de ellos aprobó y se puede observar como en esa mayoría casi todos utilizan la Intelegncia Artificial, además, vemos que las notas más altas fueron alcanzadas por estudiantes que la utilizan.
# Al separar a los estudiantes entre los que trabajan y los que no lo hacen no solo notamos una diferencia etaria, siendo los que trabajan los de mayor edad, sino también una diferencia en los promedios, en el grupo de aquellos que trabajan encontramos un promedio superior al grupos de los que no llevan a cabo la actividad laboral.
# A una institución educativa podría llamarle la atención que los estudiantes que incorporan la Iteligencia Artificial como herramienta alcanzan mejores resultados en comparación de aquellos que no lo hacen, siempre suponiendo que aquel uso lo realizan en forma de guía de aprendizaje en vez de solo pedirle que les resuelva la consigna. También destaca el insitir en ocupar horas de estudio para la materia ya que aquellos estudiantes que desaprobaron son los mismos que menos horas de estudio dedicaron.

# %% [markdown]
# ## Entrega en GitHub
#
# El trabajo debe subirse a un repositorio de GitHub.
#
# El repositorio debe incluir:
#
# - este notebook;
# - un archivo `README.md`;
# - al menos 3 commits.
#
# Ejemplos de commits:
#
# 1. `Agrega datos de estudiantes`
# 2. `Calcula indicadores principales`
# 3. `Agrega gráficos y conclusiones`
#
# El enlace del repositorio será la entrega final.
